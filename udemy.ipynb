# %% [markdown]
# Import Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# Read CSV File

# %%
udemy = pd.read_csv('C:/Users/saleh.abdallah/Downloads/Udemy Courses.csv')

# %% [markdown]
# View Sample Date

# %%
udemy.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers total_sales  num_reviews  num_lectures  \
# 0    35             3137      109795           18            68
# 1    75             1593      119475            1            41
# 2    75              482       36150            1            47
# 3    75              850       63750            3            43
# 4    75              940       70500            3            32
#
#                 level content_duration   published_timestamp  \
# 0          All Levels        1.5 hours  2014-09-18T05:07:05Z
# ...

# %% [markdown]
# No. of Subjects

# %%
udemy['subject'].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# Total no. of Courses in each Subject

# %%
udemy.groupby('subject')['course_title'].nunique()
# Out:
# subject
# Business Finance       1195
# Graphic Design          600
# Musical Instruments     676
# Web Development        1196
# Name: course_title, dtype: int64

# %% [markdown]
# Paid vs Free Courses

# %%
udemy['is_paid'].value_counts()
# Out:
# True     3372
# False     310
# Name: is_paid, dtype: int64

# %% [markdown]
# Total no. of Subscribers

# %%
udemy['num_subscribers'].sum()
# Out:
# 11761156

# %% [markdown]
# No. of Subscribers by Course Level

# %%
udemy.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %% [markdown]
# No. of Subscribers by Subject

# %%
udemy.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %% [markdown]
# Top 10 Courses by no. of Subscribers

# %%
udemy.sort_values('num_subscribers', ascending=False) .head(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 3581      41295               Learn HTML5 Programming From Scratch    False
# 3429      59014                     Coding for Entrepreneurs Basic    False
# 3371     625204                         The Web Developer Bootcamp     True
# 3420     173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3370     764164              The Complete Web Developer Course 2.0     True
# 3482      19421              Free Beginner Electric Guitar Lessons    False
# 3669     473160  Web Design for Web Developers: Build Beautiful...    False
# 3311      94430             Learn Javascript & JQuery From Scratch     True
# 3626     130064  Practical PHP: Master the Basics and Code Dyna...    False
# 3367     364426          JavaScript: Understanding the Weird Parts     True
#
#      price  num_subscribers  total_sales  num_reviews  num_lectures  \
# ...

# %% [markdown]
# Total Sales by Subject

# %%
 udemy.groupby('subject')['total_sales'].sum()
# Out:
# subject
# Business Finance       123796395
# Graphic Design          76983170
# Musical Instruments     53359055
# Web Development        630843775
# Name: total_sales, dtype: int64

# %% [markdown]
# No. of Python Courses

# %%
sum(udemy['course_title'].str.contains('Python'))
# Out:
# 29

# %% [markdown]
# List of Python Courses

# %%
udemy[udemy['course_title'].str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %% [markdown]
# No. of Courses per Year

# %%
udemy['year'] = udemy['published_timestamp'].str.split('-', expand = True)[0]
udemy.groupby('year')['course_title'].nunique()
# Out:
# year
# 2011       5
# 2012      45
# 2013     200
# 2014     490
# 2015    1014
# 2016    1202
# 2017     717
# Name: course_title, dtype: int64
